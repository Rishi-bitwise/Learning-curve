# %%
import pandas as pd
import matplotlib.pyplot as plt
from  statsmodels.datasets import sunspots
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
dataset = sunspots.load_pandas().data
series = dataset["SUNACTIVITY"][:-20]

orseries = dataset["SUNACTIVITY"][-20:]

# %%
plot_acf(series, lags= 40)

# %%
plot_pacf(series, lags = 40)

# %%
model = ARIMA(series, order=(2,0,6))
model_fit = model.fit()

print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:            SUNACTIVITY   No. Observations:                  289
# Model:                 ARIMA(2, 0, 6)   Log Likelihood               -1204.662
# Date:                Tue, 17 Feb 2026   AIC                           2429.323
# Time:                        02:19:37   BIC                           2465.987
# Sample:                             0   HQIC                          2444.014
#                                 - 289
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         49.2723      3.832     12.860      0.000      41.763      56.782
# ar.L1          1.6499      0.023     70.447      0.000       1.604       1.696
# ar.L2         -0.9770      0.022    -43.667      0.000      -1.021      -0.933
# ma.L1         -0.4165      0.060     -6.920      0.000      -0.534      -0.299
# ma.L2          0.0022      0.066      0.033      0.973      -0.127       0.131
# ma.L3         -0.0232      0.069     -0.335      0.737      -0.159       0.112
# ma.L4          0.2805      0.070      4.036      0.000       0.144       0.417
# ma.L5          0.0776      0.077      1.007      0.314      -0.073       0.229
# ma.L6          0.1786      0.063      2.826      0.005       0.055       0.302
# sigma2       241.4942     17.159     14.074      0.000     207.864     275.124
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):               146.35
# Prob(Q):                              0.83   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.29   Skew:                             1.06
# Prob(H) (two-sided):                  0.21   Kurtosis:                         5.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# c:\Users\sapta\Desktop\practice\myvenv\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
forecast = model_fit.forecast(steps = 20)

# %%
plt.figure()
plt.plot(orseries, label = "original")
plt.plot(forecast, label = "forecast")

plt.legend()
plt.show()
